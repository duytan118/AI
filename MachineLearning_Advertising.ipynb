# %% [markdown]
# <a href="https://colab.research.google.com/github/duytan118/AI/blob/main/MachineLearning_Advertising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'Advertising.csv'
data = pd.read_csv(url)
import matplotlib.pyplot as plt
data.hist()#ve histogram
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr()
print(correlation)
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
import seaborn as sns
sns.pairplot(data)

# %%
data.plot(kind = 'scatter',x='TV',y='sales',figsize = (9,9),color='black')
# Out:
# <AxesSubplot:xlabel='TV', ylabel='sales'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['TV']),y = data['sales'])#fit la ham de hoc
print(model.intercept_)#HE SO
print(model.coef_)#HE SO GOC, Y = COEF*X + INTERCEPT
model.score(X = pd.DataFrame(data['TV']),y = data['sales'])#do chinh xac
# Out:
# 7.032593549127695
# [0.04753664]
# 0.611875050850071

# %%
data.plot(kind='scatter',x='TV',y='sales',figsize=(9,9),color='black')
y_pred = model.predict(X=pd.DataFrame(data['TV']))
plt.plot(data['TV'],y_pred, color='red')

# %%
data['sales'].max()
# Out:
# 27.0

# %%
model = linear_model.LinearRegression()#tao model moi
X = pd.DataFrame([data['TV'],data['TV']**2,data['TV']**3,data['TV']**4,data['TV']**5,data['TV']**6,data['TV']**7,data['TV']**8,data['TV']**9,data['TV']**10,data['TV']**11,data['TV']**12,data['TV']**13,data['TV']**14,data['TV']**15,data['TV']**16,data['TV']**17,data['TV']**18,data['TV']**19,data['TV']**20]).T    #tuyen tinh bac 3,   .T de chuyen vi
model.fit(X,y=data['sales'])

print('Intercept cua mo hinh: ',model.intercept_)
print('Coeffient cua mo hinh: ',model.coef_)
print('Do chinh xac cua mo hinh: ',model.score(X,y=data['sales']))
# Out:
# Intercept cua mo hinh:  11.004339116866468
# Coeffient cua mo hinh:  [ 4.44223612e-67 -3.79582945e-37 -1.72312254e-41  5.11691748e-44
#   1.28103107e-47  2.13821177e-50  3.62121958e-53  4.45585564e-51
#   7.43184156e-49  1.18782627e-46  1.79735254e-44  2.52864226e-42
#   3.21487950e-40  3.51752776e-38  3.00507294e-36  1.54608669e-34
#  -2.25975652e-36  1.23844187e-38 -3.01571078e-41  2.75259066e-44]
# Do chinh xac cua mo hinh:  0.4567217599059087

# %%
import numpy as np
range = np.arange(0,300,0.1)
data.plot(kind = 'scatter',x='TV',y='sales',figsize = (9,9),color='black')
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10,range**11,range**12,range**13,range**14,range**15,range**16,range**17,range**18,range**19,range**20]).T
y_pred = model.predict(X=predictor)
plt.plot(range, y_pred, color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
